# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')     
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | grand-santi
# Processing Record 3 of Set 1 | colares
# Processing Record 4 of Set 1 | blind river
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | felipe carrillo puerto
# Processing Record 7 of Set 1 | danane
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | pacasmayo
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 1 | gat
# Processing Record 15 of Set 1 | virginia beach
# Processing Record 16 of Set 1 | blagoveshchensk
# Processing Record 17 of Set 1 | olinda
# Processing Record 18 of Set 1 | rodrigues alves
# Processing Record 19 of Set 1 | baiao
# Processing Record 20 of Set 1 | forset
# City not found. Skipping...
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | tingrela
# City not found. Skipping...
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | kostomuksha
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | tukrah
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | cayenne
# Processing Record 31 of Set 1 | karasjok
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | quelimane
# Processing Record 34 of Set 1 | puerto colombia
# Processing Record 35 of Set 1 | grindavik
# Processing Record 36 of Set 1 | santiago de cao
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | olafsvik
# Processing Record 39 of Set 1 | gilazi
# City not found. Skipping...
# Processing Record 40 of Set 1 | berga
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | huarmey
# Processing Record 43 of Set 1 | parati
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | luderitz
# Processing Record 46 of Set 1 | itacare
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | mundi
# Processing Record 1 of Set 2 | knysna
# Processing Record 2 of Set 2 | libreville
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | chicama
# Processing Record 6 of Set 2 | chake chake
# Processing Record 7 of Set 2 | agirish
# Processing Record 8 of Set 2 | marawi
# Processing Record 9 of Set 2 | orda
# Processing Record 10 of Set 2 | san jose
# Processing Record 11 of Set 2 | roquetas de mar
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | los chiles
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | tiffin
# Processing Record 16 of Set 2 | ostrovnoy
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | jumla
# Processing Record 19 of Set 2 | abnub
# Processing Record 20 of Set 2 | boddam
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | matagami
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | umm kaddadah
# Processing Record 26 of Set 2 | ihosy
# Processing Record 27 of Set 2 | santa maria
# Processing Record 28 of Set 2 | nizwa
# Processing Record 29 of Set 2 | honningsvag
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | gulmarg
# Processing Record 32 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 2 | masallatah
# Processing Record 34 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | abu dhabi
# Processing Record 36 of Set 2 | mpika
# Processing Record 37 of Set 2 | jiwani
# Processing Record 38 of Set 2 | walvis bay
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | beloha
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | sokoni
# Processing Record 43 of Set 2 | sisimiut
# Processing Record 44 of Set 2 | riyadh
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | axim
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | chelmsford
# Processing Record 49 of Set 2 | jalu
# Processing Record 50 of Set 2 | salinopolis
# Processing Record 1 of Set 3 | padang
# Processing Record 2 of Set 3 | rio grande
# Processing Record 3 of Set 3 | hellin
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 7 of Set 3 | taoudenni
# Processing Record 8 of Set 3 | rawson
# Processing Record 9 of Set 3 | beyneu
# Processing Record 10 of Set 3 | mooi river
# City not found. Skipping...
# Processing Record 11 of Set 3 | contamana
# Processing Record 12 of Set 3 | richards bay
# Processing Record 13 of Set 3 | saint-georges
# Processing Record 14 of Set 3 | bolobo
# Processing Record 15 of Set 3 | cap-aux-meules
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | itaqui
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | tabas
# Processing Record 21 of Set 3 | eresos
# Processing Record 22 of Set 3 | kangaatsiaq
# Processing Record 23 of Set 3 | batayurt
# Processing Record 24 of Set 3 | marabba
# Processing Record 25 of Set 3 | mayumba
# Processing Record 26 of Set 3 | amsterdam
# Processing Record 27 of Set 3 | manta
# Processing Record 28 of Set 3 | savannah bight
# Processing Record 29 of Set 3 | antofagasta
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | okulovka
# Processing Record 34 of Set 3 | monaghan
# Processing Record 35 of Set 3 | belyy yar
# Processing Record 36 of Set 3 | formello
# Processing Record 37 of Set 3 | kabwe
# Processing Record 38 of Set 3 | klaksvik
# Processing Record 39 of Set 3 | traiguen
# Processing Record 40 of Set 3 | roura
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | awjilah
# Processing Record 44 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 3 | humpolec
# Processing Record 47 of Set 3 | san juan bautista
# Processing Record 48 of Set 3 | berlevag
# Processing Record 49 of Set 3 | grand gaube
# Processing Record 50 of Set 3 | trelleborg
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | cockburn town
# Processing Record 3 of Set 4 | yekaterinovka
# Processing Record 4 of Set 4 | lodwar
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | yaroslavl
# Processing Record 8 of Set 4 | lasa
# Processing Record 9 of Set 4 | kamenka
# Processing Record 10 of Set 4 | domat
# Processing Record 11 of Set 4 | bengkulu
# Processing Record 12 of Set 4 | mahibadhoo
# Processing Record 13 of Set 4 | brighton
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | kajaani
# Processing Record 16 of Set 4 | qaqortoq
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | kayerkan
# Processing Record 21 of Set 4 | trairi
# Processing Record 22 of Set 4 | luau
# Processing Record 23 of Set 4 | ollioules
# Processing Record 24 of Set 4 | sorland
# Processing Record 25 of Set 4 | turiacu
# Processing Record 26 of Set 4 | el alto
# Processing Record 27 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | los llanos de aridane
# Processing Record 30 of Set 4 | roscrea
# Processing Record 31 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 4 | chancay
# Processing Record 33 of Set 4 | wexford
# Processing Record 34 of Set 4 | sigayevo
# Processing Record 35 of Set 4 | chunhuhub
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | bandarbeyla
# Processing Record 38 of Set 4 | lieksa
# Processing Record 39 of Set 4 | gamba
# Processing Record 40 of Set 4 | andenes
# Processing Record 41 of Set 4 | turukhansk
# Processing Record 42 of Set 4 | manaure
# Processing Record 43 of Set 4 | tiznit
# Processing Record 44 of Set 4 | chokwe
# Processing Record 45 of Set 4 | alto araguaia
# Processing Record 46 of Set 4 | bhaderwah
# Processing Record 47 of Set 4 | havoysund
# Processing Record 48 of Set 4 | mitu
# Processing Record 49 of Set 4 | parbatipur
# Processing Record 50 of Set 4 | ponta delgada
# Processing Record 1 of Set 5 | omboue
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | maarianhamina
# Processing Record 4 of Set 5 | moose factory
# Processing Record 5 of Set 5 | hukuntsi
# Processing Record 6 of Set 5 | marsa matruh
# Processing Record 7 of Set 5 | duz
# City not found. Skipping...
# Processing Record 8 of Set 5 | paragominas
# Processing Record 9 of Set 5 | talcahuano
# Processing Record 10 of Set 5 | la rioja
# Processing Record 11 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 5 | dhidhdhoo
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | ailigandi
# Processing Record 17 of Set 5 | dalaba
# Processing Record 18 of Set 5 | gornopravdinsk
# Processing Record 19 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | marsh harbour
# Processing Record 22 of Set 5 | jhelum
# Processing Record 23 of Set 5 | zhezkazgan
# Processing Record 24 of Set 5 | villa carlos paz
# Processing Record 25 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 26 of Set 5 | the valley
# Processing Record 27 of Set 5 | mutoko
# Processing Record 28 of Set 5 | donji milanovac
# Processing Record 29 of Set 5 | marsala
# Processing Record 30 of Set 5 | eyl
# Processing Record 31 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 5 | san rafael
# Processing Record 33 of Set 5 | jacareacanga
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | kondagaon
# Processing Record 36 of Set 5 | araouane
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | acarau
# Processing Record 39 of Set 5 | carutapera
# Processing Record 40 of Set 5 | chapais
# Processing Record 41 of Set 5 | sompeta
# Processing Record 42 of Set 5 | najran
# Processing Record 43 of Set 5 | krylovskaya
# Processing Record 44 of Set 5 | sargatskoye
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | arlit
# Processing Record 47 of Set 5 | kaputa
# Processing Record 48 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 5 | comodoro rivadavia
# Processing Record 50 of Set 5 | obudovac
# Processing Record 1 of Set 6 | bilma
# Processing Record 2 of Set 6 | sinj
# Processing Record 3 of Set 6 | vuktyl
# Processing Record 4 of Set 6 | robertsport
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | beniganj
# Processing Record 7 of Set 6 | qasigiannguit
# Processing Record 8 of Set 6 | sur
# Processing Record 9 of Set 6 | nisia floresta
# Processing Record 10 of Set 6 | samarkand
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | hobyo
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | sinop
# Processing Record 15 of Set 6 | silvan
# Processing Record 16 of Set 6 | tambura
# Processing Record 17 of Set 6 | la sarre
# Processing Record 18 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 6 | korla
# Processing Record 21 of Set 6 | charlestown
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | dingle
# Processing Record 24 of Set 6 | trinidad
# Processing Record 25 of Set 6 | cervo
# Processing Record 26 of Set 6 | thrissur
# Processing Record 27 of Set 6 | yarmouth
# Processing Record 28 of Set 6 | onguday
# Processing Record 29 of Set 6 | iracoubo
# Processing Record 30 of Set 6 | santa cruz de tenerife
# Processing Record 31 of Set 6 | oum hadjer
# Processing Record 32 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 6 | fontem
# Processing Record 34 of Set 6 | praia da vitoria
# Processing Record 35 of Set 6 | reinosa
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | aiquile
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | melnikovo
# Processing Record 40 of Set 6 | dimona
# Processing Record 41 of Set 6 | birjand
# Processing Record 42 of Set 6 | lulea
# Processing Record 43 of Set 6 | gayeri
# Processing Record 44 of Set 6 | krasnouralsk
# Processing Record 45 of Set 6 | kyzyl-suu
# Processing Record 46 of Set 6 | zagyvarekas
# Processing Record 47 of Set 6 | san jacinto
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | meulaboh
# Processing Record 50 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 7 | finspang
# Processing Record 2 of Set 7 | maun
# Processing Record 3 of Set 7 | bodden town
# Processing Record 4 of Set 7 | marzuq
# Processing Record 5 of Set 7 | thiers
# Processing Record 6 of Set 7 | hamilton
# Processing Record 7 of Set 7 | kutum
# Processing Record 8 of Set 7 | sept-iles
# Processing Record 9 of Set 7 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 7 | kamien pomorski
# Processing Record 11 of Set 7 | litomysl
# Processing Record 12 of Set 7 | dudinka
# Processing Record 13 of Set 7 | kayes
# Processing Record 14 of Set 7 | carmo do paranaiba
# Processing Record 15 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 7 | grosseto
# Processing Record 17 of Set 7 | nouadhibou
# Processing Record 18 of Set 7 | freeport
# Processing Record 19 of Set 7 | jinka
# Processing Record 20 of Set 7 | maraba
# Processing Record 21 of Set 7 | charyshskoye
# Processing Record 22 of Set 7 | gubkinskiy
# Processing Record 23 of Set 7 | matara
# Processing Record 24 of Set 7 | sillamae
# Processing Record 25 of Set 7 | yurya
# City not found. Skipping...
# Processing Record 26 of Set 7 | aksarka
# Processing Record 27 of Set 7 | hanko
# Processing Record 28 of Set 7 | shubarshi
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | general salgado
# Processing Record 31 of Set 7 | karia
# Processing Record 32 of Set 7 | madimba
# Processing Record 33 of Set 7 | akhaldaba
# Processing Record 34 of Set 7 | diplo
# Processing Record 35 of Set 7 | sechura
# Processing Record 36 of Set 7 | cap malheureux
# Processing Record 37 of Set 7 | impfondo
# Processing Record 38 of Set 7 | raudeberg
# Processing Record 39 of Set 7 | chimore
# Processing Record 40 of Set 7 | chandler
# Processing Record 41 of Set 7 | san carlos de bariloche
# Processing Record 42 of Set 7 | saint-paul
# Processing Record 43 of Set 7 | carballo
# Processing Record 44 of Set 7 | barcelos
# Processing Record 45 of Set 7 | oranjemund
# Processing Record 46 of Set 7 | burica
# City not found. Skipping...
# Processing Record 47 of Set 7 | shakiso
# Processing Record 48 of Set 7 | port blair
# Processing Record 49 of Set 7 | port-gentil
# Processing Record 50 of Set 7 | tahoua
# Processing Record 1 of Set 8 | sovetskiy
# Processing Record 2 of Set 8 | mokrous
# Processing Record 3 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 4 of Set 8 | porto nacional
# Processing Record 5 of Set 8 | urucara
# Processing Record 6 of Set 8 | marrakesh
# Processing Record 7 of Set 8 | webster
# Processing Record 8 of Set 8 | mwense
# Processing Record 9 of Set 8 | san juan
# Processing Record 10 of Set 8 | sao joao do piaui
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | qena
# Processing Record 13 of Set 8 | namibe
# Processing Record 14 of Set 8 | aleppo
# Processing Record 15 of Set 8 | parrita
# Processing Record 16 of Set 8 | khudumelapye
# Processing Record 17 of Set 8 | tazovskiy
# Processing Record 18 of Set 8 | sault sainte marie
# Processing Record 19 of Set 8 | chabahar
# Processing Record 20 of Set 8 | husavik
# Processing Record 21 of Set 8 | santa vitoria do palmar
# Processing Record 22 of Set 8 | bat khela
# Processing Record 23 of Set 8 | lexington park
# Processing Record 24 of Set 8 | otjimbingwe
# Processing Record 25 of Set 8 | druzhba
# Processing Record 26 of Set 8 | osypenko
# Processing Record 27 of Set 8 | darnah
# Processing Record 28 of Set 8 | kautokeino
# Processing Record 29 of Set 8 | agadez
# Processing Record 30 of Set 8 | bekhtery
# Processing Record 31 of Set 8 | mabaruma
# Processing Record 32 of Set 8 | great yarmouth
# Processing Record 33 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 8 | borgarnes
# Processing Record 35 of Set 8 | sitrah
# Processing Record 36 of Set 8 | kabo
# Processing Record 37 of Set 8 | kalangala
# Processing Record 38 of Set 8 | tunceli
# Processing Record 39 of Set 8 | banfora
# Processing Record 40 of Set 8 | kigoma
# Processing Record 41 of Set 8 | bobrovytsya
# Processing Record 42 of Set 8 | harper
# Processing Record 43 of Set 8 | beisfjord
# Processing Record 44 of Set 8 | nanortalik
# Processing Record 45 of Set 8 | opuwo
# Processing Record 46 of Set 8 | arak
# Processing Record 47 of Set 8 | matay
# Processing Record 48 of Set 8 | kuminskiy
# Processing Record 49 of Set 8 | khokholskiy
# City not found. Skipping...
# Processing Record 50 of Set 8 | mutsamudu
# City not found. Skipping...

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0             East London -33.0153  27.9116     64.33        85           0
# 1             Grand-Santi   4.2500 -54.3833     73.08        96          53
# 2                 Colares  38.7992  -9.4469     70.75        97         100
# 3             Blind River  46.1834 -82.9582     41.11        65         100
# 4                 Ushuaia -54.8000 -68.3000     47.86        57         100
# 5  Felipe Carrillo Puerto  19.5833 -88.0500     76.95        79          99
# 6                  Danane   7.2596  -8.1550     69.91        99          94
# 7              Bredasdorp -34.5322  20.0403     57.47        97         100
# 8            Longyearbyen  78.2186  15.6401     13.68        77          90
# 9               Pacasmayo  -7.4006 -79.5714     61.45        88          66
#
#    Wind Speed Country                 Date      Current Description
# 0       15.30      ZA  2022-10-27 01:36:37                clear sky
# 1        2.55      GF  2022-10-27 01:36:37               light rain
# 2       15.01      PT  2022-10-27 01:36:38          overcast clouds
# 3       14.27      CA  2022-10-27 01:36:38          overcast clouds
# 4       11.50      AR  2022-10-27 01:36:38  light intensity drizzle
# 5        2.62      MX  2022-10-27 01:36:39          overcast clouds
# 6        1.34      CI  2022-10-27 01:36:39          overcast clouds
# 7        2.84      ZA  2022-10-27 01:36:39          overcast clouds
# 8        4.83      SJ  2022-10-27 01:36:40          overcast clouds
# 9        9.71      PE  2022-10-27 01:36:40            broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_weather_data= city_data_df[new_column_order]

# Display sample data
city_weather_data.head()
# Out:
#           City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  East London      ZA -33.0153  27.9116     64.33        85           0
# 1  Grand-Santi      GF   4.2500 -54.3833     73.08        96          53
# 2      Colares      PT  38.7992  -9.4469     70.75        97         100
# 3  Blind River      CA  46.1834 -82.9582     41.11        65         100
# 4      Ushuaia      AR -54.8000 -68.3000     47.86        57         100
#
#    Wind Speed      Current Description
# 0       15.30                clear sky
# 1        2.55               light rain
# 2       15.01          overcast clouds
# 3       14.27          overcast clouds
# 4       11.50  light intensity drizzle

# %%
# Display the data types of each column by using the dtypes Pandas function
city_weather_data.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
